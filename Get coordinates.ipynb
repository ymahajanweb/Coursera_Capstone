# %% [markdown]
# Get the data from wikipedia page

# %%
import requests
import pandas as pd
website_url = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
from bs4 import BeautifulSoup
soup = BeautifulSoup(website_url,'lxml')
My_table = soup.find('table',{'class':'wikitable sortable'})
Neighbourhood = []
#read the table into an array
for row in My_table.find_all('tr'):
    col = row.findAll('td')
    if len(col) > 0:
        postcode = col[0].string
        county = col[1].string
        borough = col[2].string
        Neighbourhood.append([t.text.strip() for t in row.find_all('td')])
        
df = pd.DataFrame([])
#populate the dataframe from array
df = pd.DataFrame(Neighbourhood, columns=['PostalCode', 'Borough', 'Neighbourhood'])
 # Get names of indexes for which column 'Borough is Not assigned'
indexNames = df[ df['Borough'] == 'Not assigned' ].index
    
# Delete these row indexes from dataFrame
df.drop(indexNames , inplace=True)
df.head() 
df['Neighbourhood'] = df.groupby(['PostalCode', 'Borough'])['Neighbourhood'].transform(lambda x: ', '.join(set(x.dropna())))
df  = df.drop_duplicates()
df.loc[df['Neighbourhood'] =='Not assigned','Neighbourhood']=df['Borough']
df
# Out:
#     PostalCode           Borough  \
# 2          M3A        North York
# 3          M4A        North York
# 4          M5A  Downtown Toronto
# 6          M6A        North York
# 8          M7A      Queen's Park
# 10         M9A         Etobicoke
# 11         M1B       Scarborough
# 14         M3B        North York
# 15         M4B         East York
# 17         M5B  Downtown Toronto
# 19         M6B        North York
# 22         M9B         Etobicoke
# 27         M1C       Scarborough
# 31         M3C        North York
# 33         M4C         East York
# 34         M5C  Downtown Toronto
# 35         M6C              York
# 38         M9C         Etobicoke
# 42         M1E       Scarborough
# 47         M4E      East Toronto
# 48         M5E  Downtown Toronto
# 49         M6E              York
# 53         M1G       Scarborough
# 56         M4G         East York
# 57         M5G  Downtown Toronto
# 58         M6G  Downtown Toronto
# 62         M1H       Scarborough
# 63         M2H        North York
# 64         M3H        North York
# 67         M4H         East York
# ..         ...               ...
# 168        M4R   Central Toronto
# 169        M5R   Central Toronto
# 172        M6R      West Toronto
# 174        M7R       Mississauga
# 176        M9R         Etobicoke
# 180        M1S       Scarborough
# 183        M4S   Central Toronto
# 184        M5S  Downtown Toronto
# 186        M6S      West Toronto
# 191        M1T       Scarborough
# 196        M4T   Central Toronto
# 198        M5T  Downtown Toronto
# 205        M1V       Scarborough
# 211        M4V   Central Toronto
# 216        M5V  Downtown Toronto
# 225        M8V         Etobicoke
# 228        M9V         Etobicoke
# 236        M1W       Scarborough
# 239        M4W  Downtown Toronto
# 240        M5W  Downtown Toronto
# 243        M8W         Etobicoke
# 245        M9W         Etobicoke
# 246        M1X       Scarborough
# 249        M4X  Downtown Toronto
# 251        M5X  Downtown Toronto
# 255        M8X         Etobicoke
# 262        M4Y  Downtown Toronto
# 265        M7Y      East Toronto
# 266        M8Y         Etobicoke
# 282        M8Z         Etobicoke
#
#                                          Neighbourhood
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                            Regent Park, Harbourfront
# 6                     Lawrence Manor, Lawrence Heights
# 8                                         Queen's Park
# 10                                    Islington Avenue
# 11                                      Rouge, Malvern
# 14                                     Don Mills North
# 15                     Woodbine Gardens, Parkview Hill
# 17                            Ryerson, Garden District
# 19                                           Glencairn
# 22   Cloverdale, Princess Gardens, Islington, West ...
# 27              Port Union, Highland Creek, Rouge Hill
# 31                    Don Mills South, Flemingdon Park
# 33                                    Woodbine Heights
# 34                                      St. James Town
# 35                                  Humewood-Cedarvale
# 38   Old Burnhamthorpe, Eringate, Bloordale Gardens...
# 42                   Morningside, Guildwood, West Hill
# 47                                         The Beaches
# 48                                         Berczy Park
# 49                                 Caledonia-Fairbanks
# 53                                              Woburn
# 56                                             Leaside
# 57                                  Central Bay Street
# 58                                            Christie
# 62                                           Cedarbrae
# 63                                   Hillcrest Village
# 64     Bathurst Manor, Downsview North, Wilson Heights
# 67                                    Thorncliffe Park
# ..                                                 ...
# 168                                 North Toronto West
# 169                North Midtown, Yorkville, The Annex
# 172                             Parkdale, Roncesvalles
# 174              Canada Post Gateway Processing Centre
# 176  Martin Grove Gardens, St. Phillips, Kingsview ...
# 180                                          Agincourt
# 183                                         Davisville
# 184                     Harbord, University of Toronto
# 186                                 Runnymede, Swansea
# 191            Tam O'Shanter, Sullivan, Clarks Corners
# 196                        Summerhill East, Moore Park
# 198          Grange Park, Chinatown, Kensington Market
# 205  Steeles East, Milliken, Agincourt North, L'Amo...
# 211  Rathnelly, Deer Park, South Hill, Forest Hill ...
# 216  Railway Lands, CN Tower, Island airport, Bathu...
# 225       Mimico South, Humber Bay Shores, New Toronto
# 228  Silverstone, South Steeles, Humbergate, Thistl...
# 236                                    L'Amoreaux West
# 239                                           Rosedale
# 240                    Stn A PO Boxes 25 The Esplanade
# 243                             Long Branch, Alderwood
# 245                                          Northwest
# 246                                        Upper Rouge
# 249                        Cabbagetown, St. James Town
# 251             First Canadian Place, Underground city
# 255      The Kingsway, Old Mill North, Montgomery Road
# 262                               Church and Wellesley
# 265  Business Reply Mail Processing Centre 969 Eastern
# 266  Kingsway Park South East, Mimico NE, King's Mi...
# 282  Royal York South West, The Queensway West, Sou...
#
# [103 rows x 3 columns]

# %% [markdown]
# Read from the csv file into the dataframe

# %%
# Load the Pandas libraries with alias 'pd' 
# Read data from file 
data = pd.read_csv("http://cocl.us/Geospatial_data/Geospatial_coordinates.csv") 
# change the column name of the first column
data.columns = ['PostalCode','Latitude','Logitude']
#Merge the data of two dataframes
df_final = pd.merge(df, data, on='PostalCode')
# Out:
#   PostalCode   Latitude   Logitude
# 0        M1B  43.806686 -79.194353
# 1        M1C  43.784535 -79.160497
# 2        M1E  43.763573 -79.188711
# 3        M1G  43.770992 -79.216917
# 4        M1H  43.773136 -79.239476
